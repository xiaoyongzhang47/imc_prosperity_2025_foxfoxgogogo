# %%
import pandas as pd
import numpy as np

# %%
prices_round_1_day_m2_df = pd.read_csv(filepath_or_buffer='./round-1-island-data-bottle/prices_round_1_day_-2.csv',sep=';')
prices_round_1_day_m1_df = pd.read_csv(filepath_or_buffer='./round-1-island-data-bottle/prices_round_1_day_-1.csv',sep=';')
prices_round_1_day_0_df = pd.read_csv(filepath_or_buffer='./round-1-island-data-bottle/prices_round_1_day_0.csv',sep=';')

# %%
trades_round_1_day_m2_df = pd.read_csv(filepath_or_buffer='./round-1-island-data-bottle/trades_round_1_day_-2.csv',sep=';')
trades_round_1_day_m1_df = pd.read_csv(filepath_or_buffer='./round-1-island-data-bottle/trades_round_1_day_-1.csv',sep=';')
trades_round_1_day_0_df = pd.read_csv(filepath_or_buffer='./round-1-island-data-bottle/trades_round_1_day_0.csv',sep=';')

# %%
prices_round_1_day_m2_df.head(10)
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -2          0  RAINFOREST_RESIN         9996             1       9995.0
# 1   -2          0              KELP         1998            26          NaN
# 2   -2          0         SQUID_INK         1998            26          NaN
# 3   -2        100         SQUID_INK         1999             5       1998.0
# 4   -2        100  RAINFOREST_RESIN        10000             5       9995.0
# 5   -2        100              KELP         2000             5       1999.0
# 6   -2        200              KELP         1999             1       1998.0
# 7   -2        200         SQUID_INK         1997            31          NaN
# 8   -2        200  RAINFOREST_RESIN         9996             1       9995.0
# 9   -2        300  RAINFOREST_RESIN         9996             1       9995.0
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# ...

# %%
trades_round_1_day_m2_df.head(10)
# Out:
#    timestamp  buyer  seller            symbol   currency   price  quantity
# 0          0    NaN     NaN              KELP  SEASHELLS  2002.0         1
# 1          0    NaN     NaN  RAINFOREST_RESIN  SEASHELLS  9996.0         1
# 2          0    NaN     NaN  RAINFOREST_RESIN  SEASHELLS  9996.0         1
# 3          0    NaN     NaN         SQUID_INK  SEASHELLS  2002.0         1
# 4        100    NaN     NaN              KELP  SEASHELLS  2002.0         6
# 5        100    NaN     NaN         SQUID_INK  SEASHELLS  2001.0         6
# 6       1000    NaN     NaN              KELP  SEASHELLS  1999.0        10
# 7       1000    NaN     NaN         SQUID_INK  SEASHELLS  1999.0        10
# 8       1100    NaN     NaN              KELP  SEASHELLS  1999.0         1
# 9       1100    NaN     NaN         SQUID_INK  SEASHELLS  1999.0         1

# %%
prices_round_1_day_m2_df[prices_round_1_day_m2_df['product']=='KELP'].head(10)
# Out:
#     day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 1    -2          0    KELP         1998            26          NaN
# 5    -2        100    KELP         2000             5       1999.0
# 6    -2        200    KELP         1999             1       1998.0
# 10   -2        300    KELP         1999            27          NaN
# 13   -2        400    KELP         1999            20          NaN
# 17   -2        500    KELP         2001             1       1999.0
# 18   -2        600    KELP         1999            30          NaN
# 22   -2        700    KELP         1999            28          NaN
# 25   -2        800    KELP         2001             1       1999.0
# 29   -2        900    KELP         2000             2       1999.0
#
#     bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 1            NaN          NaN           NaN         2002            26
# 5            6.0       1998.0          20.0         2002            20
# ...
